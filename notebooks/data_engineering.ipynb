# %%
import pandas as pd
import numpy as np

# %%
raw_confirmed = pd.read_csv('../data/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')

# %%
raw_confirmed_exus = raw_confirmed[raw_confirmed['Country/Region'] != 'US']
raw_confirmed_us = raw_confirmed[raw_confirmed['Country/Region'] == 'US']

# %%
us_ts_cols = list(raw_confirmed_us['Province/State'].unique())
ts_index = list(raw_confirmed_us.columns[5:])

# %%
us_ts_data = raw_confirmed_us[['Province/State'] + ts_index].T

# %%
us_ts_data.columns
# Out:
# Int64Index([ 98,  99, 100, 101, 102, 103, 104, 105, 106, 107,
#             ...
#             394, 395, 396, 397, 398, 399, 414, 417, 431, 448],
#            dtype='int64', length=247)

# %%
us_ts_data.columns = us_ts_data.loc['Province/State'].values

# %%
us_ts_data
# Out:
#         Washington New York California Massachusetts Diamond Princess  \
# 1/23/20          0        0          0             0                0
# 1/24/20          0        0          0             0                0
# 1/25/20          0        0          0             0                0
# 1/26/20          0        0          0             0                0
# 1/27/20          0        0          0             0                0
# 1/28/20          0        0          0             0                0
# 1/29/20          0        0          0             0                0
# 1/30/20          0        0          0             0                0
# 1/31/20          0        0          0             0                0
# 2/1/20           0        0          0             0                0
# 2/2/20           0        0          0             0                0
# 2/3/20           0        0          0             0                0
# ...

# %%
us_ts_data = us_ts_data.iloc[1:].copy()

# %%
d = us_ts_data.iloc[-13:].pct_change().iloc[1:]

# %%
d['Washington'][0]
# Out:
# 0.3707865168539326

# %%
e = d.copy(deep=True)

# %%
e.mean()
# Out:
# Washington          0.190626
# New York            0.474353
# California          0.226304
# Massachusetts       0.182659
# Diamond Princess    0.005358
#                       ...
# New Castle, DE           NaN
# Alabama                  inf
# Puerto Rico              inf
# Guam                     inf
# Virgin Islands           inf
# Length: 247, dtype: float64

# %%
std_us = d.std().dropna()
(d[std_us.index] - d[std_us.index].mean()) / std_us.values
# Out:
#          Washington  New York  California  Massachusetts  Diamond Princess  \
# 3/11/20    1.249902 -0.788900    0.046943      -1.143659         -0.403549
# 3/12/20    0.118108  0.064444    0.365439      -0.349210         -0.403549
# 3/13/20    0.655210 -0.742735    0.815289      -0.333610         -0.403549
# 3/14/20   -1.273654 -0.884830   -0.338332      -0.462706         -0.403549
# 3/15/20   -0.461361 -0.311654    0.436836       0.043799         -0.403549
# 3/16/20    1.493577 -0.596763    1.331773       0.141463          1.233872
# 3/17/20   -0.002503  1.128280    0.440127      -0.579718         -0.403549
# 3/18/20   -1.722268 -0.046193   -2.466061      -1.392197         -0.403549
# 3/19/20    1.154268  2.631068    0.677943       2.453678         -0.403549
# 3/20/20   -0.576303  0.290279    0.164658       0.582971          2.801615
# 3/21/20   -0.097940 -0.253813   -1.105756       0.674739         -0.403549
# ...

# %%
(d[std_us.index] / std_us.values).cumsum()
# Out:
#          Washington   New York  California  Massachusetts  Diamond Princess  \
# 3/11/20    2.572413   1.057476    3.758248       0.248538          0.000000
# 3/12/20    4.013032   2.968296    7.834991       1.291524          0.000000
# 3/13/20    5.990753   4.071938   12.361585       2.350111          0.000000
# 3/14/20    6.039611   5.033484   15.734558       3.279602          0.000000
# 3/15/20    6.900761   6.568206   19.882699       4.715598          0.000000
# 3/16/20    9.716850   7.817819   24.925777       6.249258          1.637420
# 3/17/20   11.036858  10.792475   29.077208       7.061736          1.637420
# 3/18/20   10.637101  12.592658   30.322452       7.061736          1.637420
# 3/19/20   13.113881  17.070102   34.711700      10.907611          1.637420
# 3/20/20   13.860089  19.206757   38.587662      12.882779          4.842584
# 3/21/20   15.084660  20.799320   41.193210      14.949714          4.842584
# ...

# %%
# Out:
# array([0.14413958, 0.25691012, 0.060977  , 0.13120218, 0.01327645,
#        0.08965018, 0.12725209, 0.3939078 , 0.17925804, 0.53182612,
#        0.19309811, 0.17622421, 0.43481253, 0.18238606, 0.22038061,
#        0.1111491 , 0.32962264, 0.21444377, 0.28172894, 0.24620122,
#        0.24680651, 0.22427103, 0.23084199, 0.33367348, 0.33412543,
#        0.27493462, 0.2321052 , 0.28062527, 0.38949731, 0.49063489,
#        0.34682628, 0.51790396, 0.29810438, 0.46841731, 0.48827436,
#        1.10984913, 1.37771411, 0.35771996, 0.46995021])

# %%
pd.concat([raw_confirmed_us['Province/State'], raw_confirmed_exus['Country/Region']], axis=1)a
# Out:
#     Province/State Country/Region
# 0              NaN       Thailand
# 1              NaN          Japan
# 2              NaN      Singapore
# 3              NaN          Nepal
# 4              NaN       Malaysia
# ..             ...            ...
# 482            NaN       Dominica
# 483            NaN        Grenada
# 484            NaN     Mozambique
# 485            NaN          Syria
# 486            NaN    Timor-Leste
#
# [487 rows x 2 columns]

# %%
raw_confirmed.index
# Out:
# Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#               ...
#               nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#              dtype='float64', length=487)
